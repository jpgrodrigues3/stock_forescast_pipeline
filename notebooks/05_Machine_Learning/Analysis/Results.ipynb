# %% [markdown]
# ## REULTADOS ARIMA

# %%
df = spark.sql("SELECT * FROM Machine_Learning.results.results_arima LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 0ff57043-b984-414c-91b6-5d1f0ac0833e, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 7b7d9ec5-f0be-4401-b183-88ffa7aaefab)

# %% [markdown]
# ## RESULTADOS BASELINE MEAN

# %%
df = spark.sql("SELECT * FROM Machine_Learning.results.results_baseline_mean LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 0ff57043-b984-414c-91b6-5d1f0ac0833e, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 30a68d7b-47a9-4619-9fa4-875c3703d3ed)

# %% [markdown]
# ## RESULTADOS REGRESSÃO LINEAR

# %%
df = spark.sql("SELECT * FROM Machine_Learning.results.results_linear_regression_products_w_no_data LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 0ff57043-b984-414c-91b6-5d1f0ac0833e, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 3308bbf4-e19d-45d5-893d-781a0a171c40)

# %% [markdown]
# ## RESULTADOS XGBOOST

# %%
df = spark.sql("SELECT * FROM Machine_Learning.results.results_xgboost_products_w_no_data LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 0ff57043-b984-414c-91b6-5d1f0ac0833e, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 85746d45-0fb4-4968-abf7-c18d645b58d8)

# %% [markdown]
# ## REORDER FORECAST

# %%
df = spark.sql("SELECT * FROM Machine_Learning.predictions.reorder_forecast LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 0ff57043-b984-414c-91b6-5d1f0ac0833e, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, c95a7fc9-e9c3-4fc0-ab8e-ca8b0e8ed246)

# %% [markdown]
# ## REORDER FORECAST 2

# %%
df = spark.sql("SELECT * FROM Machine_Learning.predictions.reorder_forecast_2 LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 0ff57043-b984-414c-91b6-5d1f0ac0833e, 8, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, f5b5838f-87d9-4478-8f11-faafed7750fe)
