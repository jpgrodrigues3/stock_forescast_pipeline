# %% [markdown]
# # **Silver Layer** - Transformação e Limpeza da Tabela Cities

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lower, trim, when
from delta import *

# -------------------------------------------
# 2. Leitura dos dados da camada RAW
# -------------------------------------------
df_cities_raw = spark.table("Bronze_Data.cities.raw_cities_data")

# -------------------------------------------
# 3. Normalização textual e tipos
# -------------------------------------------
for col_name in ["store_id", "storetype_id", "city_code", "country_id"]:
    df_cities_raw = df_cities_raw.withColumn(col_name, trim(lower(col(col_name).cast("string"))))

# -------------------------------------------
# 4. Limpeza dos dados
# -------------------------------------------
# store_size deve ser positivo
df_cities_clean = df_cities_raw.withColumn("store_size", 
     when(col("store_size").cast("float") > 0, col("store_size").cast("float")).otherwise(None))

# Eliminar linhas com store_id nulo (chave primária)
df_cities_clean = df_cities_clean.filter(col("store_id").isNotNull())

# Remover duplicados mantendo a primeira ocorrência
df_cities_clean = df_cities_clean.dropDuplicates(["store_id"])
# Out:
# StatementMeta(, ade0afec-cee4-41cf-8ca6-617a65b17a17, 3, Finished, Available, Finished)

# %%
from pyspark.sql.functions import col, when

# Mapping of incorrect/corrupted city names to correct ones
corrections = {
    'eski?ehir': 'eskisehir',
    '?zmir': 'izmir',
    'adapazar?': 'adapazari',
    'diyarbak?r': 'diyarbakir',
    'sanl?urfa': 'sanliurfa'
}

# Apply the replacements using when/otherwise chain
df_cities_clean = df_cities_clean.withColumn(
    "city_code",
    when(col("city_code") == "eski?ehir", "eskisehir")
    .when(col("city_code") == "?zmir", "izmir")
    .when(col("city_code") == "adapazar?", "adapazari")
    .when(col("city_code") == "diyarbak?r", "diyarbakir")
    .when(col("city_code") == "sanl?urfa", "sanliurfa")
    .otherwise(col("city_code"))
)
# Out:
# StatementMeta(, ade0afec-cee4-41cf-8ca6-617a65b17a17, 4, Finished, Available, Finished)

# %%
# # -------------------------------------------
# # 5. Visualização final para verificação
# # -------------------------------------------
# df_cities_clean.printSchema()
# df_cities_clean.show(100)

# print("\n✅ Silver Layer - Cities concluída com sucesso.")
# Out:
# StatementMeta(, ade0afec-cee4-41cf-8ca6-617a65b17a17, 5, Finished, Available, Finished)
# root
#  |-- store_id: string (nullable = true)
#  |-- storetype_id: string (nullable = true)
#  |-- store_size: float (nullable = true)
#  |-- city_id_old: string (nullable = true)
#  |-- country_id: string (nullable = true)
#  |-- city_code: string (nullable = true)
#
# +--------+------------+----------+-----------+----------+-------------+
# |store_id|storetype_id|store_size|city_id_old|country_id|    city_code|
# +--------+------------+----------+-----------+----------+-------------+
# |   s0002|        st04|      39.0|       C007|    turkey|        adana|
# |   s0003|        st03|      17.0|       C014|    turkey|     istanbul|
# |   s0005|        st04|      19.0|       C001|    turkey|      denizli|
# |   s0007|        st03|      16.0|       C014|    turkey|     istanbul|
# |   s0010|        st04|      17.0|       C014|    turkey|     istanbul|
# |   s0012|        st04|      28.0|       C005|    turkey|      antalya|
# |   s0014|        st03|      14.0|       C014|    turkey|     istanbul|
# |   s0015|        st04|      19.0|       C014|    turkey|     istanbul|
# |   s0016|        st03|      11.0|       C014|    turkey|     istanbul|
# |   s0020|        st04|      36.0|       C014|    turkey|     istanbul|
# |   s0022|        st04|      16.0|       C014|    turkey|     istanbul|
# |   s0023|        st04|      31.0|       C008|    turkey|    sanliurfa|
# |   s0026|        st04|      41.0|       C014|    turkey|     istanbul|
# |   s0030|        st03|      13.0|       C006|    turkey|        konya|
# |   s0032|        st03|      14.0|       C019|    turkey|          van|
# |   s0036|        st04|      21.0|       C001|    turkey|      denizli|
# |   s0038|        st01|      63.0|       C004|    turkey|        bursa|
# |   s0039|        st03|      15.0|       C014|    turkey|     istanbul|
# |   s0040|        st04|      42.0|       C017|    turkey|kahramanmaras|
# |   s0041|        st03|       8.0|       C013|    turkey|       samsun|
# |   s0045|        st04|      17.0|       C008|    turkey|    sanliurfa|
# |   s0046|        st04|      26.0|       C017|    turkey|kahramanmaras|
# |   s0050|        st04|      31.0|       C014|    turkey|     istanbul|
# |   s0052|        st04|      17.0|       C014|    turkey|     istanbul|
# |   s0055|        st04|      24.0|       C014|    turkey|     istanbul|
# |   s0056|        st04|      42.0|       C015|    turkey|    eskisehir|
# |   s0058|        st04|      17.0|       C014|    turkey|     istanbul|
# |   s0059|        st03|      15.0|       C014|    turkey|     istanbul|
# |   s0061|        st04|      35.0|       C019|    turkey|          van|
# |   s0062|        st04|      47.0|       C014|    turkey|     istanbul|
# |   s0067|        st04|      16.0|       C014|    turkey|     istanbul|
# |   s0068|        st03|      14.0|       C003|    turkey|        izmir|
# |   s0071|        st04|      32.0|       C014|    turkey|     istanbul|
# |   s0072|        st04|      29.0|       C014|    turkey|     istanbul|
# |   s0073|        st04|      19.0|       C014|    turkey|     istanbul|
# |   s0076|        st03|      11.0|       C014|    turkey|     istanbul|
# |   s0077|        st03|      12.0|       C014|    turkey|     istanbul|
# |   s0080|        st03|      14.0|       C014|    turkey|     istanbul|
# |   s0083|        st04|      23.0|       C010|    turkey|       mersin|
# |   s0085|        st01|      60.0|       C014|    turkey|     istanbul|
# |   s0086|        st03|      12.0|       C003|    turkey|        izmir|
# |   s0088|        st04|      20.0|       C009|    turkey|    gaziantep|
# |   s0089|        st03|      18.0|       C014|    turkey|     istanbul|
# |   s0091|        st04|      19.0|       C013|    turkey|       samsun|
# |   s0092|        st04|      23.0|       C005|    turkey|      antalya|
# |   s0094|        st04|      45.0|       C006|    turkey|        konya|
# |   s0095|        st02|      44.0|       C014|    turkey|     istanbul|
# |   s0097|        st04|      45.0|       C014|    turkey|     istanbul|
# |   s0099|        st03|      14.0|       C014|    turkey|     istanbul|
# |   s0102|        st04|      27.0|       C018|    turkey|      erzurum|
# |   s0104|        st04|      47.0|       C002|    turkey|       ankara|
# |   s0107|        st04|      19.0|       C014|    turkey|     istanbul|
# |   s0108|        st04|      35.0|       C016|    turkey|    adapazari|
# |   s0109|        st04|      20.0|       C005|    turkey|      antalya|
# |   s0120|        st03|      16.0|       C014|    turkey|     istanbul|
# |   s0122|        st04|      23.0|       C008|    turkey|    sanliurfa|
# |   s0126|        st04|      34.0|       C014|    turkey|     istanbul|
# |   s0131|        st04|      22.0|       C012|    turkey|      kayseri|
# |   s0132|        st04|      31.0|       C011|    turkey|   diyarbakir|
# |   s0136|        st03|      12.0|       C005|    turkey|      antalya|
# |   s0141|        st03|      12.0|       C005|    turkey|      antalya|
# |   s0142|        st04|      31.0|       C006|    turkey|        konya|
# |   s0143|        st03|      13.0|       C014|    turkey|     istanbul|
# +--------+------------+----------+-----------+----------+-------------+
#
#
# ✅ Silver Layer - Cities concluída com sucesso.

# %%
# -------------------------------------------
# 6. Escrita dos dados limpos na camada SILVER (Delta)
# -------------------------------------------
df_cities_clean.write.format("delta").mode("overwrite").saveAsTable("Silver_Data.cities.silver_cities_data")
# Out:
# StatementMeta(, ade0afec-cee4-41cf-8ca6-617a65b17a17, 6, Finished, Available, Finished)
